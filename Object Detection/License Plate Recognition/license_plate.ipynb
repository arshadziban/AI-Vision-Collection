# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data = r"C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\dataset\data.yaml",  # path to dataset YAML
    epochs=5,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:02<00:00, 1.94MB/s]
# Ultralytics 8.3.81  Python-3.10.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Load a trained YOLO model
model = YOLO(r"C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\runs\detect\train\weights\best.pt") 

# Perform object detection on an image
results = model(r"C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\image.png", save =True)  

# Display results
results[0].show()
# Out:
# image 1/1 C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\image.png: 448x640 1 License_Plate, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict

# %%
# Load a trained YOLO model
model = YOLO(r"C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\runs\detect\train\weights\best.pt") 

# Perform object detection on an image
results = model(r"C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\video\video2.mp4", save =True)  

# Display results
results[0].show()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\video\video2.mp4: 384x640 2 License_Plates, 10.2ms
# video 1/1 (frame 2/750) C:\Users\Arshad Ziban\Desktop\Skills\AI-Vision-Collection\Object Detection\License Plate Recognition\video\video2.mp4: 384x640 2 License_Plates, 9.6ms
# ...
